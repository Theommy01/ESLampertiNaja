# %% [markdown]
# # Rabbit 100

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/ES/bench_dataset
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/ES/bench_dataset

# %%
import numpy as np

# %%
root = "/Users/fedelampe11/Downloads/ES/Reinforcement-Learning-for-SCA-main/bench_dataset/"
test_meta = np.load("test_meta.npy", mmap_mode='r')
test_targets = np.load("test_targets.npy",mmap_mode='r')
test_windows = np.load("test_windows.npy",mmap_mode='r')

train_meta = np.load("train_meta.npy",mmap_mode='r')
train_targets = np.load("train_targets.npy",mmap_mode='r')
train_windows = np.load("train_windows.npy",mmap_mode='r')

valid_meta = np.load("valid_meta.npy",mmap_mode='r')
valid_targets = np.load("valid_targets.npy",mmap_mode='r')
valid_windows = np.load("valid_windows.npy",mmap_mode='r')

# %%
print(test_meta.shape)
print(test_targets.shape)
print(test_windows.shape)
print('\n')
print(train_meta.shape)
print(train_targets.shape)
print(train_windows.shape)
print('\n')
print(valid_meta.shape)
print(valid_targets.shape)
print(valid_windows.shape)

DIM_TEST = 12800
# Out:
# (12800, 2)
# (12800, 1)
# (12800, 2570)
#
#
# (102400, 2)
# (102400, 1)
# (102400, 2570)
#
#
# (12800, 2)
# (12800, 1)
# (12800, 2570)

# %%
print(test_meta[0])  #(primo byte plaintext, primo byte key) -- key cambia ogni 102
print(test_meta[100])
print(test_meta[200])
print(train_windows.dtype)
# Out:
# [225  51]
# [171  14]
# [226 210]
# float32

# %%
# Importing the library
import psutil

# Getting % usage of virtual_memory ( 3rd field)
print('RAM memory % used:', psutil.virtual_memory()[2])

profiling_traces = np.concatenate((train_windows, valid_windows))
profiling_targets = np.concatenate((train_targets, valid_targets))

print('RAM memory % used:', psutil.virtual_memory()[2])

#np.save('/home/gchiari/Documents/Reinforcement-Learning-for-SCA-main/data/FreeRTOS100/experiment_value/profiling_traces.npy', profiling_traces)
#np.save('/home/gchiari/Documents/Reinforcement-Learning-for-SCA-main/data/FreeRTOS100/experiment_value/profiling_targets.npy', profiling_targets)
#
#np.save('/home/gchiari/Documents/Reinforcement-Learning-for-SCA-main/data/FreeRTOS100/experiment_value/attack_traces.npy', test_windows)
#np.save('/home/gchiari/Documents/Reinforcement-Learning-for-SCA-main/data/FreeRTOS100/experiment_value/attack_targets.npy', test_targets)
# Out:
# RAM memory % used: 8.1
# RAM memory % used: 17.3

# %%
key = []
for i in range(DIM_TEST):
    key.append(test_meta[i][1])

np.save("bench_key.npy", key)

# %%
from metaqnn.attack.utils import generate_precomputed_values_file

plaintexts = []
#for i in range(test_meta.shape[0]):
for i in range(DIM_TEST):
    plaintexts.append(test_meta[i][0])

generate_precomputed_values_file(plaintext=np.array(plaintexts), byte=0, save_folder="")
# Out:
# array([[248, 225,  17, ..., 156, 192, 114],
#        [168, 159,  60, ...,  79, 129,  96],
#        [ 43, 103,   1, ...,  66, 230, 191],
#        ...,
#        [124,  99, 123, ..., 176,  22, 187],
#        [167, 196,  61, ..., 146, 245,  56],
#        [104,  66, 230, ..., 103,   1,  48]])
